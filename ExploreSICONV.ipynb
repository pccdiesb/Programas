# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Apr  2 19:49:25 2019

@author: rodar
"""

import numpy as np
import pandas as pd

import seaborn as sns

# %%
# importando arquivos (trocar caminho para máquina local)

#file1 = 'C:\\Users\\rodar\\Documents\\Ciencia de Dados\\IESB\\TrabalhoFinal\\ProjetoEvasao\\DADOS\\BASE_DATASCI_HENRIQUE.CSV'
#file2 = 'C:\\Users\\rodar\\Documents\\Ciencia de Dados\\IESB\\TrabalhoFinal\\ProjetoEvasao\\DADOS\\DadosIESB.CSV'
filesiconv = 'C:\\Users\\rodar\\Documents\\Ciencia de Dados\\IESB\\TrabalhoFinal\\siconv\\amostra\\amostrasiconv.CSV'

# %%
print(filesiconv)
# Out:
# C:\Users\rodar\Documents\Ciencia de Dados\IESB\TrabalhoFinal\siconv\amostra\amostrasiconv.CSV

# %%
df = pd.read_csv(filesiconv, sep = '|', error_bad_lines=False)
# Out:
# C:\Users\rodar\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(6)
# Out:
#    id_proposta uf_proponente munic_proponente  cod_munic_ibge  cod_orgao_sup  \
# 0       288734            PI    DOM INOCENCIO       2203453.0          53000
# 1       288734            PI    DOM INOCENCIO       2203453.0          53000
# 2       288734            PI    DOM INOCENCIO       2203453.0          53000
# 3       288734            PI    DOM INOCENCIO       2203453.0          53000
# 4       288734            PI    DOM INOCENCIO       2203453.0          53000
# 5       288734            PI    DOM INOCENCIO       2203453.0          53000
#
#                       desc_orgao_sup                natureza_juridica  \
# 0  MINISTERIO DA INTEGRACAO NACIONAL  Administração Pública Municipal
# 1  MINISTERIO DA INTEGRACAO NACIONAL  Administração Pública Municipal
# 2  MINISTERIO DA INTEGRACAO NACIONAL  Administração Pública Municipal
# 3  MINISTERIO DA INTEGRACAO NACIONAL  Administração Pública Municipal
# 4  MINISTERIO DA INTEGRACAO NACIONAL  Administração Pública Municipal
# 5  MINISTERIO DA INTEGRACAO NACIONAL  Administração Pública Municipal
#
#   nr_proposta dia_proposta  cod_orgao    ...    desc_situacao_empenho  \
# 0  43989/2010   19/04/2010      22203    ...                  Enviado
# 1  43989/2010   19/04/2010      22203    ...                  Enviado
# 2  43989/2010   19/04/2010      22203    ...                  Enviado
# 3  43989/2010   19/04/2010      22203    ...                  Enviado
# 4  43989/2010   19/04/2010      22203    ...                  Enviado
# 5  43989/2010   19/04/2010      22203    ...                  Enviado
#
#   valor_empenho  nr_mov_fin identif_fornecedor  \
# 0      190000.0     4797073     01857346000173
# 1      190000.0     3914825     05859092000183
# 2      190000.0     3914824     01857346000173
# 3     -190000.0     4797073     01857346000173
# 4     -190000.0     3914825     05859092000183
# 5     -190000.0     3914824     01857346000173
#
#                                      nome_fornecedor       tp_mov_financeira  \
# 0                           R. MELO CONSTRUTORA LTDA  PAGAMENTO A FAVORECIDO
# 1  JLJ AUDITORIA, CONSULTORIA E PROJETOS S/C LTDA...  PAGAMENTO A FAVORECIDO
# 2                           R. MELO CONSTRUTORA LTDA  PAGAMENTO A FAVORECIDO
# 3                           R. MELO CONSTRUTORA LTDA  PAGAMENTO A FAVORECIDO
# 4  JLJ AUDITORIA, CONSULTORIA E PROJETOS S/C LTDA...  PAGAMENTO A FAVORECIDO
# 5                           R. MELO CONSTRUTORA LTDA  PAGAMENTO A FAVORECIDO
#
#      data_pag  nr_dl      desc_dl   vl_pago
# 0  24/11/2016    905  NOTA FISCAL  24211.52
# 1  09/06/2016   1570  NOTA FISCAL   5563.65
# 2  06/06/2016    854  NOTA FISCAL  88360.97
# 3  24/11/2016    905  NOTA FISCAL  24211.52
# 4  09/06/2016   1570  NOTA FISCAL   5563.65
# 5  06/06/2016    854  NOTA FISCAL  88360.97
#
# [6 rows x 68 columns]

# %%
df.describe().T
# Out:
#                                    count          mean           std  \
# id_proposta                    3109111.0  7.118231e+05  2.462343e+05
# cod_munic_ibge                 3107752.0  3.528118e+06  2.430330e+05
# cod_orgao_sup                  3109111.0  3.827041e+04  4.009187e+03
# cod_orgao                      3109111.0  3.820018e+04  4.032621e+03
# identif_proponente             3109111.0  5.901374e+13  1.039109e+13
# vl_global_prop                 3109111.0  2.399769e+07  1.424299e+07
# vl_repasse_prop                3109111.0  2.235824e+07  1.400645e+07
# vl_contrapartida_prop          3109111.0  1.639458e+06  4.681478e+05
# nr_convenio                    3109111.0  7.917276e+05  2.777698e+04
# dias_prest_contas              3109111.0  4.892622e+01  1.510457e+01
# qtde_convenios                 3109111.0  1.000000e+00  0.000000e+00
# qtd_ta                         3056887.0  6.645919e+00  2.560656e+00
# qtd_prorroga                   1222480.0  1.061183e+00  4.533458e-01
# vl_global_conv                 3109111.0  2.399769e+07  1.424299e+07
# vl_repasse_conv                3109111.0  2.235824e+07  1.400645e+07
# vl_contrapartida_conv          3109111.0  1.639458e+06  4.681478e+05
# vl_empenhado_conv              3109111.0  1.074400e+07  4.682964e+06
# vl_desembolsado_conv           3108831.0  9.561015e+06  4.217692e+06
# vl_saldo_reman_tesouro           61645.0  1.237223e+05  2.653357e+05
# vl_saldo_reman_convenente        36105.0  1.019199e+04  2.342795e+04
# vl_rendimento_aplicacao        2931030.0  5.894505e+05  3.796365e+05
# vl_ingresso_contrapartida      3037093.0  9.879665e+05  5.669457e+05
# vl_saldo_conta                 2024526.0  2.927899e+06  9.187856e+05
# cod_programa_emenda            3109111.0  3.819838e+12  4.015662e+11
# nr_emenda                      3108959.0  2.569205e+07  8.283679e+06
# beneficiario_emenda            3109111.0  5.901362e+13  1.039131e+13
# valor_repasse_proposta_emenda  3109111.0  1.226283e+07  2.090586e+10
# valor_repasse_emenda           3109111.0  3.658859e+05  3.068488e+06
# id_empenho                     3109111.0  2.746623e+05  7.526683e+04
# tipo_nota                      3109111.0  1.275987e+00  8.514770e-01
# valor_empenho                  3109111.0  3.340821e+05  1.265119e+06
# nr_mov_fin                     3109111.0  3.293650e+06  1.071051e+06
# vl_pago                        3109111.0  6.645863e+03  5.614784e+04
#
#                                         min           25%           50%  \
# id_proposta                    2.123130e+05  3.859070e+05  8.867890e+05
# cod_munic_ibge                 1.100015e+06  3.550308e+06  3.550308e+06
# cod_orgao_sup                  2.000000e+04  3.800000e+04  3.800000e+04
# cod_orgao                      2.010100e+04  3.800000e+04  3.800000e+04
# identif_proponente             7.290002e+08  6.096500e+13  6.096500e+13
# vl_global_prop                 9.000000e+01  8.164716e+06  3.557852e+07
# vl_repasse_prop                9.000000e+01  6.498331e+06  3.379460e+07
# vl_contrapartida_prop          0.000000e+00  1.666384e+06  1.783917e+06
# nr_convenio                    7.331720e+05  7.551580e+05  8.114850e+05
# dias_prest_contas              0.000000e+00  3.000000e+01  6.000000e+01
# qtde_convenios                 1.000000e+00  1.000000e+00  1.000000e+00
# qtd_ta                         1.000000e+00  5.000000e+00  5.000000e+00
# qtd_prorroga                   1.000000e+00  1.000000e+00  1.000000e+00
# vl_global_conv                 9.000000e+01  8.164716e+06  3.557852e+07
# vl_repasse_conv                9.000000e+01  6.498331e+06  3.379460e+07
# vl_contrapartida_conv          0.000000e+00  1.666384e+06  1.783917e+06
# vl_empenhado_conv              0.000000e+00  7.148289e+06  1.365168e+07
# vl_desembolsado_conv           9.000000e+01  6.498331e+06  1.205092e+07
# vl_saldo_reman_tesouro         1.000000e-02  1.297615e+04  4.268197e+04
# vl_saldo_reman_convenente      1.000000e-02  3.654500e+02  2.238140e+03
# vl_rendimento_aplicacao        2.600000e+01  1.015262e+05  8.842050e+05
# vl_ingresso_contrapartida      0.000000e+00  6.388783e+05  6.388783e+05
# vl_saldo_conta                 0.000000e+00  3.206297e+06  3.206297e+06
# cod_programa_emenda            2.010120e+12  3.800020e+12  3.800020e+12
# nr_emenda                      1.000000e+07  1.997002e+07  2.520000e+07
# beneficiario_emenda            7.290002e+08  6.096500e+13  6.096500e+13
# valor_repasse_proposta_emenda  1.000000e+00  1.000000e+05  2.000000e+05
# valor_repasse_emenda           1.000000e+00  1.000000e+05  2.000000e+05
# id_empenho                     7.061500e+04  2.044650e+05  2.591990e+05
# tipo_nota                      1.000000e+00  1.000000e+00  1.000000e+00
# valor_empenho                 -5.933860e+07  1.000000e+05  2.000000e+05
# nr_mov_fin                     1.029010e+05  2.832443e+06  3.347296e+06
# vl_pago                       -5.347300e+02  7.079400e+02  1.545470e+03
#
#                                         75%           max
# id_proposta                    8.867890e+05  1.361556e+06
# cod_munic_ibge                 3.550308e+06  5.300108e+06
# cod_orgao_sup                  3.800000e+04  8.100000e+04
# cod_orgao                      3.800000e+04  8.100000e+04
# identif_proponente             6.096500e+13  9.871488e+13
# vl_global_prop                 3.557852e+07  8.521845e+07
# vl_repasse_prop                3.379460e+07  7.711440e+07
# vl_contrapartida_prop          1.783917e+06  2.258045e+07
# nr_convenio                    8.114850e+05  8.745790e+05
# dias_prest_contas              6.000000e+01  8.110000e+02
# qtde_convenios                 1.000000e+00  1.000000e+00
# qtd_ta                         1.000000e+01  1.600000e+01
# qtd_prorroga                   1.000000e+00  1.500000e+01
# vl_global_conv                 3.557852e+07  8.521845e+07
# vl_repasse_conv                3.379460e+07  7.711440e+07
# vl_contrapartida_conv          1.783917e+06  2.258045e+07
# vl_empenhado_conv              1.365168e+07  7.711440e+07
# vl_desembolsado_conv           1.205092e+07  7.711440e+07
# vl_saldo_reman_tesouro         1.311399e+05  6.890955e+06
# vl_saldo_reman_convenente      1.463468e+04  4.305954e+05
# vl_rendimento_aplicacao        8.842050e+05  1.457601e+06
# vl_ingresso_contrapartida      1.666384e+06  2.258045e+07
# vl_saldo_conta                 3.206297e+06  4.785365e+07
# cod_programa_emenda            3.800020e+12  8.100020e+12
# nr_emenda                      2.910000e+07  9.048001e+07
# beneficiario_emenda            6.096500e+13  9.871488e+13
# valor_repasse_proposta_emenda  2.000000e+05  3.686262e+13
# valor_repasse_emenda           2.000000e+05  7.711440e+07
# id_empenho                     3.741440e+05  3.742890e+05
# tipo_nota                      1.000000e+00  1.500000e+01
# valor_empenho                  2.998488e+05  6.157566e+07
# nr_mov_fin                     4.067159e+06  5.089781e+06
# vl_pago                        2.904180e+03  7.954000e+06

# %%
df.dtypes
# Out:
# id_proposta                        int64
# uf_proponente                     object
# munic_proponente                  object
# cod_munic_ibge                   float64
# cod_orgao_sup                      int64
# desc_orgao_sup                    object
# natureza_juridica                 object
# nr_proposta                       object
# dia_proposta                      object
# cod_orgao                          int64
# desc_orgao                        object
# modalidade                        object
# identif_proponente                 int64
# nm_proponente                     object
# sit_proposta                      object
# vl_global_prop                   float64
# vl_repasse_prop                  float64
# vl_contrapartida_prop            float64
# nr_convenio                        int64
# dia_assin_conv                    object
# sit_convenio                      object
# subsituacao_conv                  object
# situacao_publicacao               object
# instrumento_ativo                 object
# ind_opera_obtv                    object
# dia_publ_conv                     object
# dia_inic_vigenc_conv              object
# dia_fim_vigenc_conv               object
# dias_prest_contas                  int64
# dia_limite_prest_contas           object
#                                   ...
# vl_desembolsado_conv             float64
# vl_saldo_reman_tesouro           float64
# vl_saldo_reman_convenente        float64
# vl_rendimento_aplicacao          float64
# vl_ingresso_contrapartida        float64
# vl_saldo_conta                   float64
# qualif_proponente                 object
# cod_programa_emenda                int64
# nr_emenda                        float64
# nome_parlamentar                  object
# beneficiario_emenda                int64
# ind_impositivo                    object
# tipo_parlamentar                  object
# valor_repasse_proposta_emenda    float64
# valor_repasse_emenda             float64
# id_empenho                         int64
# nr_empenho                        object
# tipo_nota                          int64
# desc_tipo_nota                    object
# data_emissao                      object
# desc_situacao_empenho             object
# valor_empenho                    float64
# nr_mov_fin                         int64
# identif_fornecedor                object
# nome_fornecedor                   object
# tp_mov_financeira                 object
# data_pag                          object
# nr_dl                             object
# desc_dl                           object
# vl_pago                          float64
# Length: 68, dtype: object

# %%
df.sample(5)
# Out:
#          id_proposta uf_proponente munic_proponente  cod_munic_ibge  \
# 2892438       886789            SP        SAO PAULO       3550308.0
# 1896562       886789            SP        SAO PAULO       3550308.0
# 3055910      1084491            RS      VALE DO SOL       4322533.0
# 1115658       645832            RN            NATAL       2408102.0
# 2568184       886789            SP        SAO PAULO       3550308.0
#
#          cod_orgao_sup                                desc_orgao_sup  \
# 2892438          38000              MINISTERIO DO TRABALHO E EMPREGO
# 1896562          38000              MINISTERIO DO TRABALHO E EMPREGO
# 3055910          36000                           MINISTERIO DA SAUDE
# 1115658          20129  SEC.ESPEC.DE AGRIC.FAMIL.E DO DESENV.AGRARIO
# 2568184          38000              MINISTERIO DO TRABALHO E EMPREGO
#
#                       natureza_juridica nr_proposta dia_proposta  cod_orgao  \
# 2892438  Organização da Sociedade Civil  42481/2014   19/06/2014      38000
# 1896562  Organização da Sociedade Civil  42481/2014   19/06/2014      38000
# 3055910  Organização da Sociedade Civil  24718/2016   10/05/2016      36000
# 1115658  Organização da Sociedade Civil  47623/2012   25/11/2012      20129
# 2568184  Organização da Sociedade Civil  42481/2014   19/06/2014      38000
#
#            ...    desc_situacao_empenho valor_empenho  nr_mov_fin  \
# 2892438    ...                  Enviado     500699.64     3137236
# 1896562    ...                  Enviado     400000.00     3761054
# 3055910    ...                  Enviado     250000.00     4895847
# 1115658    ...                  Enviado    1017232.40     1724545
# 2568184    ...                  Enviado     150000.00     2740917
#
#         identif_fornecedor                                    nome_fornecedor  \
# 2892438        ******60850                                  SAMIRA SCHATZMANN
# 1896562     06157430000106                                  ECOS TURISMO LTDA
# 3055910     79805263000128  KSS COMERCIO E INDUSTRIA DE EQUIPAMENTOS MEDIC...
# 1115658        ******65034                   SIDILON MAURICIO FERREIRA MENDES
# 2568184        ******91407                               MARCOS AURELIO SOUZA
#
#                        tp_mov_financeira    data_pag  \
# 2892438  PAGAMENTO A FAVORECIDO COM OBTV  30/07/2015
# 1896562  PAGAMENTO A FAVORECIDO COM OBTV  20/06/2016
# 3055910  PAGAMENTO A FAVORECIDO COM OBTV  14/06/2018
# 1115658  PAGAMENTO A FAVORECIDO COM OBTV  04/09/2013
# 2568184  PAGAMENTO A FAVORECIDO COM OBTV  26/12/2014
#
#                                    nr_dl                         desc_dl  \
# 2892438     Samira Schatzmann_072015_liq              FOLHA DE PAGAMENTO
# 1896562                      Ano 2_22215            NOTA FISCAL / FATURA
# 3055910                             8098                     NOTA FISCAL
# 1115658                              049  RECIBO DE PAGAMENTO A AUTONOMO
# 2568184  Marcos Aurelio Souza_122014_liq              FOLHA DE PAGAMENTO
#
#           vl_pago
# 2892438   2834.57
# 1896562   4103.10
# 3055910  27900.00
# 1115658   2555.00
# 2568184   1335.50
#
# [5 rows x 68 columns]

# %%
df.shape
# Out:
# (3109111, 68)

# %%
df_RO = df[df.uf_proponente == 'RO']

# %%
print(df_RO.shape)
# Out:
# (1542, 68)

# %%
df_RO.sample(10)
# Out:
#          id_proposta uf_proponente   munic_proponente  cod_munic_ibge  \
# 3028727      1016759            RO          JI-PARANA       1100122.0
# 1154617       850714            RO          ARIQUEMES       1100023.0
# 1107926       590707            RO        CACAULANDIA       1100601.0
# 1102487       490351            RO  COLORADO DO OESTE       1100064.0
# 10483         324339            RO             CACOAL       1100049.0
# 3006623       919760            RO          JI-PARANA       1100122.0
# 3035596      1057187            RO      VALE DO ANARI       1101757.0
# 3032850      1023003            RO        PORTO VELHO       1100205.0
# 3039763      1061846            RO        PORTO VELHO       1100205.0
# 10428         324339            RO             CACOAL       1100049.0
#
#          cod_orgao_sup                     desc_orgao_sup  \
# 3028727          36000                MINISTERIO DA SAUDE
# 1154617          52000               MINISTERIO DA DEFESA
# 1107926          42000              MINISTERIO DA CULTURA
# 1102487          53000  MINISTERIO DA INTEGRACAO NACIONAL
# 10483            51000              MINISTERIO DO ESPORTE
# 3006623          36000                MINISTERIO DA SAUDE
# 3035596          52000               MINISTERIO DA DEFESA
# 3032850          36000                MINISTERIO DA SAUDE
# 3039763          53000  MINISTERIO DA INTEGRACAO NACIONAL
# 10428            51000              MINISTERIO DO ESPORTE
#
#                                          natureza_juridica nr_proposta  \
# 3028727                    Administração Pública Municipal  44414/2015
# 1154617                    Administração Pública Municipal  22161/2014
# 1107926                    Administração Pública Municipal  20957/2012
# 1102487                    Administração Pública Municipal  52542/2011
# 10483                      Administração Pública Municipal  76033/2010
# 3006623                    Administração Pública Municipal  54299/2014
# 3035596                    Administração Pública Municipal   6138/2016
# 3032850                     Organização da Sociedade Civil  47224/2015
# 3039763  Administração Pública Estadual ou do Distrito ...  10064/2016
# 10428                      Administração Pública Municipal  76033/2010
#
#         dia_proposta  cod_orgao    ...     desc_situacao_empenho  \
# 3028727   05/10/2015      36000    ...                   Enviado
# 1154617   27/02/2014      52000    ...                   Enviado
# 1107926   16/05/2012      42000    ...                   Enviado
# 1102487   23/09/2011      53000    ...                   Enviado
# 10483     24/06/2010      51000    ...                   Enviado
# 3006623   21/11/2014      36000    ...                   Enviado
# 3035596   04/03/2016      52000    ...                   Enviado
# 3032850   05/11/2015      36000    ...                   Enviado
# 3039763   10/03/2016      20602    ...                   Enviado
# 10428     24/06/2010      51000    ...                   Enviado
#
#         valor_empenho  nr_mov_fin identif_fornecedor  \
# 3028727     424994.00     4906947     05458908000167
# 1154617    1893000.00     3908166     05646969000158
# 1107926     100000.00     4160931     14224773000166
# 1102487    2000000.00     2870092     22862072000180
# 10483       170000.00     1200463        ******94253
# 3006623     287999.28     4523348     17567352000126
# 3035596     800000.00     4737583     34151100000211
# 3032850     300000.00     4682445     33383829000170
# 3039763     770000.00     4672092     05530834000122
# 10428       170000.00     1202887        ******29200
#
#                                       nome_fornecedor  \
# 3028727                        SANTOS & CARVALHO LTDA
# 1154617      MCC - MONTE CRISTO CONSTRUCOES LTDA - ME
# 1107926                       ZICO DIAS DE PAULA - ME
# 1102487                  CONSTRUTORA DALLA VALLE LTDA
# 10483                    PETY CRISTINE ZACHEU MARTINS
# 3006623                   W. G. S. CONSTRUCOES EIRELI
# 3035596                                    SOTREQ S/A
# 3032850  ENGECOM ENGENHARIA COMERCIO E INDUSTRIA LTDA
# 3039763                        DUNAS COMERCIAL EIRELI
# 10428            ANDREIA CRISTINA PINHEIRO DOS SANTOS
#
#                        tp_mov_financeira    data_pag            nr_dl  \
# 3028727  PAGAMENTO A FAVORECIDO COM OBTV  26/06/2018              057
# 1154617  PAGAMENTO A FAVORECIDO COM OBTV  05/09/2016                5
# 1107926           PAGAMENTO A FAVORECIDO  10/03/2015              168
# 1102487           PAGAMENTO A FAVORECIDO  03/12/2014  201400000000048
# 10483             PAGAMENTO A FAVORECIDO  11/10/2012           3º mes
# 3006623  PAGAMENTO A FAVORECIDO COM OBTV  25/09/2017              110
# 3035596  PAGAMENTO A FAVORECIDO COM OBTV  20/02/2018        000067674
# 3032850  PAGAMENTO A FAVORECIDO COM OBTV  03/01/2018              168
# 3039763  PAGAMENTO A FAVORECIDO COM OBTV  27/02/2018              693
# 10428             PAGAMENTO A FAVORECIDO  03/10/2012           3º mes
#
#                                 desc_dl    vl_pago
# 3028727                     NOTA FISCAL   26136.16
# 1154617                     NOTA FISCAL  131130.96
# 1107926                     NOTA FISCAL    1250.00
# 1102487                     NOTA FISCAL   77505.43
# 10483    RECIBO DE PAGAMENTO A AUTONOMO     473.00
# 3006623                     NOTA FISCAL  101849.99
# 3035596                     NOTA FISCAL  526400.00
# 3032850                     NOTA FISCAL   48327.67
# 3039763                     NOTA FISCAL   37899.97
# 10428    RECIBO DE PAGAMENTO A AUTONOMO     473.00
#
# [10 rows x 68 columns]

# %%
df['natureza_juridica'].value_counts()
# Out:
# Organização da Sociedade Civil                           2995148
# Administração Pública Municipal                            78483
# Administração Pública Estadual ou do Distrito Federal      32501
# Empresa pública/Sociedade de economia mista                 1544
# Consórcio Público                                           1435
# Name: natureza_juridica, dtype: int64

# %%
# %matplotlib inline

# %%
df['natureza_juridica'].value_counts().plot.bar()

# %%
NO = ['RR', 'RO', 'AC', 'AP', 'TO', 'AM', 'PA'] # 7

# %%
SU = ['RS', 'PR', 'SC'] # 4

# %%
SE = ['SP', 'MG', 'RJ', 'ES'] # 4

# %%
NE = ['MA', 'PI', 'CE', 'BA','PE', 'SE', 'AL', 'PB', 'RN'] # 9

# %%
CO = ['DF', 'GO', 'MT','MS'] # 4

# %%
print(NO)
# Out:
# ['RR', 'RO', 'AC', 'AP', 'TO', 'AM', 'PA']

# %%
df.uf_proponente.isin(NO)
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9           True
# 10          True
# 11          True
# 12          True
# 13          True
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 3109081    False
# 3109082    False
# 3109083    False
# 3109084    False
# 3109085    False
# 3109086    False
# 3109087    False
# 3109088    False
# 3109089    False
# 3109090    False
# 3109091    False
# 3109092    False
# 3109093    False
# 3109094    False
# 3109095    False
# 3109096    False
# 3109097    False
# 3109098    False
# 3109099    False
# 3109100    False
# 3109101    False
# 3109102    False
# 3109103    False
# 3109104    False
# 3109105    False
# 3109106    False
# 3109107    False
# 3109108    False
# 3109109    False
# 3109110    False
# Name: uf_proponente, Length: 3109111, dtype: bool

# %%
df_regNO= df[df.uf_proponente.isin(NO)]

# %%
df_regNO.shape
# Out:
# (17811, 68)

# %%
df_regSU = df[df.uf_proponente.isin(SU)]

# %%
df_regSU.shape
# Out:
# (35116, 68)

# %%
df_regSU.sample(10).T
# Out:
#                                                                  3040601  \
# id_proposta                                                      1057584
# uf_proponente                                                         RS
# munic_proponente                                           QUATRO IRMAOS
# cod_munic_ibge                                               4.31531e+06
# cod_orgao_sup                                                      56000
# desc_orgao_sup                                    MINISTERIO DAS CIDADES
# natureza_juridica                        Administração Pública Municipal
# nr_proposta                                                    6479/2016
# dia_proposta                                                  07/03/2016
# cod_orgao                                                          56000
# desc_orgao                                        MINISTERIO DAS CIDADES
# modalidade                                           CONTRATO DE REPASSE
# identif_proponente                                         4215994000114
# nm_proponente                                 MUNICIPIO DE QUATRO IRMAOS
# sit_proposta                        Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                    252044
# vl_repasse_prop                                                   251784
# vl_contrapartida_prop                                                260
# nr_convenio                                                       828634
# dia_assin_conv                                                24/10/2016
# sit_convenio                                                 Em execução
# subsituacao_conv                                                     NaN
# situacao_publicacao                                            Publicado
# instrumento_ativo                                                    SIM
# ind_opera_obtv                                                       SIM
# dia_publ_conv                                                 28/10/2016
# dia_inic_vigenc_conv                                          24/10/2016
# dia_fim_vigenc_conv                                           31/10/2019
# dias_prest_contas                                                     30
# dia_limite_prest_contas                                       30/11/2019
# ...                                                                  ...
# vl_desembolsado_conv                                              125892
# vl_saldo_reman_tesouro                                               NaN
# vl_saldo_reman_convenente                                            NaN
# vl_rendimento_aplicacao                                              NaN
# vl_ingresso_contrapartida                                            225
# vl_saldo_conta                                                   16472.3
# qualif_proponente                        BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                        5600020160014
# nr_emenda                                                      2.098e+07
# nome_parlamentar                                             AFONSO HAMM
# beneficiario_emenda                                        4215994000114
# ind_impositivo                                                       SIM
# tipo_parlamentar                                              INDIVIDUAL
# valor_repasse_proposta_emenda                                     251784
# valor_repasse_emenda                                              251784
# id_empenho                                                        273236
# nr_empenho                                                  2016NE800547
# tipo_nota                                                              1
# desc_tipo_nota                                          Empenho Original
# data_emissao                                                  05/05/2016
# desc_situacao_empenho                                            Enviado
# valor_empenho                                                     251784
# nr_mov_fin                                                       4982302
# identif_fornecedor                                        01341214000194
# nome_fornecedor                CONCISA PAVIMENTACAO E TERRAPLENAGEM LTDA
# tp_mov_financeira                        PAGAMENTO A FAVORECIDO COM OBTV
# data_pag                                                      14/08/2018
# nr_dl                                                               6365
# desc_dl                                                      NOTA FISCAL
# vl_pago                                                          19470.7
#
#                                                                          3104440  \
# id_proposta                                                              1231675
# uf_proponente                                                                 RS
# munic_proponente                                                    PORTO ALEGRE
# cod_munic_ibge                                                        4.3149e+06
# cod_orgao_sup                                                              22000
# desc_orgao_sup                 MINISTÉRIO DA AGRICULTURA, PECUARIA E ABASTECI...
# natureza_juridica              Administração Pública Estadual ou do Distrito ...
# nr_proposta                                                           72564/2017
# dia_proposta                                                          03/07/2017
# cod_orgao                                                                  22000
# desc_orgao                     MINISTÉRIO DA AGRICULTURA, PECUARIA E ABASTECI...
# modalidade                                                   CONTRATO DE REPASSE
# identif_proponente                                                93021632000112
# nm_proponente                    SECRETARIA DA AGRICULTURA, PECUARIA E IRRIGACAO
# sit_proposta                                Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                       7.22374e+07
# vl_repasse_prop                                                      6.95274e+07
# vl_contrapartida_prop                                                   2.71e+06
# nr_convenio                                                               850469
# dia_assin_conv                                                        31/10/2017
# sit_convenio                                                         Em execução
# subsituacao_conv                                                             NaN
# situacao_publicacao                                                    Publicado
# instrumento_ativo                                                            SIM
# ind_opera_obtv                                                               SIM
# dia_publ_conv                                                         08/11/2017
# dia_inic_vigenc_conv                                                  31/10/2017
# dia_fim_vigenc_conv                                                   30/10/2019
# dias_prest_contas                                                             60
# dia_limite_prest_contas                                               29/12/2019
# ...                                                                          ...
# vl_desembolsado_conv                                                 6.95274e+07
# vl_saldo_reman_tesouro                                                       NaN
# vl_saldo_reman_convenente                                                    NaN
# vl_rendimento_aplicacao                                                      NaN
# vl_ingresso_contrapartida                                               2.71e+06
# vl_saldo_conta                                                       3.95933e+06
# qualif_proponente                                BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                                2200020170036
# nr_emenda                                                              7.122e+07
# nome_parlamentar                                    BANCADA DO RIO GRANDE DO SUL
# beneficiario_emenda                                               93021632000112
# ind_impositivo                                                               NÃO
# tipo_parlamentar                                                         BANCADA
# valor_repasse_proposta_emenda                                           9.75e+07
# valor_repasse_emenda                                                 6.95274e+07
# id_empenho                                                                325154
# nr_empenho                                                          2017NE801394
# tipo_nota                                                                      1
# desc_tipo_nota                                                  Empenho Original
# data_emissao                                                          13/12/2017
# desc_situacao_empenho                                                    Enviado
# valor_empenho                                                         3.0113e+06
# nr_mov_fin                                                               4887999
# identif_fornecedor                                                14767899000187
# nome_fornecedor                GRA ASSESSORIA E CONSULTORIA EM NEGOCIOS INTER...
# tp_mov_financeira                                PAGAMENTO A FAVORECIDO COM OBTV
# data_pag                                                              25/06/2018
# nr_dl                                                                       2088
# desc_dl                                                              NOTA FISCAL
# vl_pago                                                                   237846
#
#                                                                    3994     \
# id_proposta                                                         312891
# uf_proponente                                                           PR
# munic_proponente                                                  CEU AZUL
# cod_munic_ibge                                                  4.1053e+06
# cod_orgao_sup                                                        53000
# desc_orgao_sup                           MINISTERIO DA INTEGRACAO NACIONAL
# natureza_juridica                          Administração Pública Municipal
# nr_proposta                                                     66340/2010
# dia_proposta                                                    01/06/2010
# cod_orgao                                                            53000
# desc_orgao                               MINISTERIO DA INTEGRACAO NACIONAL
# modalidade                                                        CONVENIO
# identif_proponente                                          76206473000101
# nm_proponente                                        MUNICIPIO DE CEU AZUL
# sit_proposta                          Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                      103980
# vl_repasse_prop                                                     100000
# vl_contrapartida_prop                                                 3980
# nr_convenio                                                         746006
# dia_assin_conv                                                  31/12/2010
# sit_convenio                      Prestação de Contas enviada para Análise
# subsituacao_conv                                                       NaN
# situacao_publicacao                                              Publicado
# instrumento_ativo                                                      SIM
# ind_opera_obtv                                                         NÃO
# dia_publ_conv                                                   20/01/2011
# dia_inic_vigenc_conv                                            20/01/2011
# dia_fim_vigenc_conv                                             03/06/2015
# dias_prest_contas                                                       30
# dia_limite_prest_contas                                         03/07/2015
# ...                                                                    ...
# vl_desembolsado_conv                                                100000
# vl_saldo_reman_tesouro                                             6587.82
# vl_saldo_reman_convenente                                              NaN
# vl_rendimento_aplicacao                                                NaN
# vl_ingresso_contrapartida                                             3980
# vl_saldo_conta                                                         NaN
# qualif_proponente                          BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                          5300020100015
# nr_emenda                                                         3.22e+07
# nome_parlamentar                                        HERMES PARCIANELLO
# beneficiario_emenda                                         76206473000101
# ind_impositivo                                                         NÃO
# tipo_parlamentar                                                INDIVIDUAL
# valor_repasse_proposta_emenda                                       100000
# valor_repasse_emenda                                                100000
# id_empenho                                                           95712
# nr_empenho                                                    2010NE900208
# tipo_nota                                                                1
# desc_tipo_nota                                            Empenho Original
# data_emissao                                                    02/07/2010
# desc_situacao_empenho                                              Enviado
# valor_empenho                                                       100000
# nr_mov_fin                                                         2084392
# identif_fornecedor                                          13060641000183
# nome_fornecedor                GMS COMERCIO DE MOVEIS PARA ESCRITORIO LTDA
# tp_mov_financeira                                   PAGAMENTO A FAVORECIDO
# data_pag                                                        25/05/2012
# nr_dl                                                                 2647
# desc_dl                                                        NOTA FISCAL
# vl_pago                                                               3446
#
#                                                                          3103482  \
# id_proposta                                                              1231675
# uf_proponente                                                                 RS
# munic_proponente                                                    PORTO ALEGRE
# cod_munic_ibge                                                        4.3149e+06
# cod_orgao_sup                                                              22000
# desc_orgao_sup                 MINISTÉRIO DA AGRICULTURA, PECUARIA E ABASTECI...
# natureza_juridica              Administração Pública Estadual ou do Distrito ...
# nr_proposta                                                           72564/2017
# dia_proposta                                                          03/07/2017
# cod_orgao                                                                  22000
# desc_orgao                     MINISTÉRIO DA AGRICULTURA, PECUARIA E ABASTECI...
# modalidade                                                   CONTRATO DE REPASSE
# identif_proponente                                                93021632000112
# nm_proponente                    SECRETARIA DA AGRICULTURA, PECUARIA E IRRIGACAO
# sit_proposta                                Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                       7.22374e+07
# vl_repasse_prop                                                      6.95274e+07
# vl_contrapartida_prop                                                   2.71e+06
# nr_convenio                                                               850469
# dia_assin_conv                                                        31/10/2017
# sit_convenio                                                         Em execução
# subsituacao_conv                                                             NaN
# situacao_publicacao                                                    Publicado
# instrumento_ativo                                                            SIM
# ind_opera_obtv                                                               SIM
# dia_publ_conv                                                         08/11/2017
# dia_inic_vigenc_conv                                                  31/10/2017
# dia_fim_vigenc_conv                                                   30/10/2019
# dias_prest_contas                                                             60
# dia_limite_prest_contas                                               29/12/2019
# ...                                                                          ...
# vl_desembolsado_conv                                                 6.95274e+07
# vl_saldo_reman_tesouro                                                       NaN
# vl_saldo_reman_convenente                                                    NaN
# vl_rendimento_aplicacao                                                      NaN
# vl_ingresso_contrapartida                                               2.71e+06
# vl_saldo_conta                                                       3.95933e+06
# qualif_proponente                                BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                                2200020170036
# nr_emenda                                                              7.122e+07
# nome_parlamentar                                    BANCADA DO RIO GRANDE DO SUL
# beneficiario_emenda                                               93021632000112
# ind_impositivo                                                               NÃO
# tipo_parlamentar                                                         BANCADA
# valor_repasse_proposta_emenda                                           9.75e+07
# valor_repasse_emenda                                                 6.95274e+07
# id_empenho                                                                314114
# nr_empenho                                                          2017NE800834
# tipo_nota                                                                      1
# desc_tipo_nota                                                  Empenho Original
# data_emissao                                                          14/09/2017
# desc_situacao_empenho                                                    Enviado
# valor_empenho                                                        1.87796e+07
# nr_mov_fin                                                               4888401
# identif_fornecedor                                                04685837001144
# nome_fornecedor                            SOLUCOES INTEGRADAS VERDES VALES LTDA
# tp_mov_financeira                                PAGAMENTO A FAVORECIDO COM OBTV
# data_pag                                                              19/06/2018
# nr_dl                                                                     016660
# desc_dl                                                              NOTA FISCAL
# vl_pago                                                                   100000
#
#                                                                 1171892  \
# id_proposta                                                      895357
# uf_proponente                                                        RS
# munic_proponente                                                SARANDI
# cod_munic_ibge                                              4.32011e+06
# cod_orgao_sup                                                     36000
# desc_orgao_sup                                      MINISTERIO DA SAUDE
# natureza_juridica                        Organização da Sociedade Civil
# nr_proposta                                                  45482/2014
# dia_proposta                                                 22/07/2014
# cod_orgao                                                         36000
# desc_orgao                                          MINISTERIO DA SAUDE
# modalidade                                                     CONVENIO
# identif_proponente                                       89753917000170
# nm_proponente                              HOSPITAL COMUNITARIO SARANDI
# sit_proposta                       Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                   974800
# vl_repasse_prop                                                  974800
# vl_contrapartida_prop                                                 0
# nr_convenio                                                      810788
# dia_assin_conv                                               24/09/2014
# sit_convenio                   Prestação de Contas enviada para Análise
# subsituacao_conv                                                    NaN
# situacao_publicacao                                           Publicado
# instrumento_ativo                                                   SIM
# ind_opera_obtv                                                      SIM
# dia_publ_conv                                                29/09/2014
# dia_inic_vigenc_conv                                         24/09/2014
# dia_fim_vigenc_conv                                          12/03/2018
# dias_prest_contas                                                    60
# dia_limite_prest_contas                                      11/05/2018
# ...                                                                 ...
# vl_desembolsado_conv                                             974800
# vl_saldo_reman_tesouro                                           114358
# vl_saldo_reman_convenente                                           NaN
# vl_rendimento_aplicacao                                             NaN
# vl_ingresso_contrapartida                                           NaN
# vl_saldo_conta                                                        0
# qualif_proponente                       BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                       3600020140009
# nr_emenda                                                     3.195e+07
# nome_parlamentar                                             ENIO BACCI
# beneficiario_emenda                                      89753917000170
# ind_impositivo                                                      SIM
# tipo_parlamentar                                             INDIVIDUAL
# valor_repasse_proposta_emenda                                     1e+06
# valor_repasse_emenda                                             374800
# id_empenho                                                       232342
# nr_empenho                                                 2014NE801286
# tipo_nota                                                             1
# desc_tipo_nota                                         Empenho Original
# data_emissao                                                 29/07/2014
# desc_situacao_empenho                                           Enviado
# valor_empenho                                                    600000
# nr_mov_fin                                                      3752564
# identif_fornecedor                                       61100244000130
# nome_fornecedor                                              FANEM LTDA
# tp_mov_financeira                       PAGAMENTO A FAVORECIDO COM OBTV
# data_pag                                                     14/06/2016
# nr_dl                                                            050687
# desc_dl                                                     NOTA FISCAL
# vl_pago                                                           10000
#
#                                                                          3046865  \
# id_proposta                                                              1084509
# uf_proponente                                                                 PR
# munic_proponente                                                        RIO AZUL
# cod_munic_ibge                                                       4.12201e+06
# cod_orgao_sup                                                              36000
# desc_orgao_sup                                               MINISTERIO DA SAUDE
# natureza_juridica                                 Organização da Sociedade Civil
# nr_proposta                                                           24735/2016
# dia_proposta                                                          10/05/2016
# cod_orgao                                                                  36000
# desc_orgao                                                   MINISTERIO DA SAUDE
# modalidade                                                              CONVENIO
# identif_proponente                                                80759111000115
# nm_proponente                        HOSPITAL DE CARIDADE SAO FRANCISCO DE ASSIS
# sit_proposta                                Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                            499990
# vl_repasse_prop                                                           499990
# vl_contrapartida_prop                                                          0
# nr_convenio                                                               832755
# dia_assin_conv                                                        01/11/2016
# sit_convenio                            Prestação de Contas enviada para Análise
# subsituacao_conv                                                             NaN
# situacao_publicacao                                                    Publicado
# instrumento_ativo                                                            SIM
# ind_opera_obtv                                                               SIM
# dia_publ_conv                                                         11/11/2016
# dia_inic_vigenc_conv                                                  01/11/2016
# dia_fim_vigenc_conv                                                   27/06/2018
# dias_prest_contas                                                             60
# dia_limite_prest_contas                                               26/08/2018
# ...                                                                          ...
# vl_desembolsado_conv                                                      499990
# vl_saldo_reman_tesouro                                                   57490.5
# vl_saldo_reman_convenente                                                    NaN
# vl_rendimento_aplicacao                                                      NaN
# vl_ingresso_contrapartida                                                    NaN
# vl_saldo_conta                                                                 0
# qualif_proponente                                BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                                3600020160033
# nr_emenda                                                              2.847e+07
# nome_parlamentar                                                     SANDRO ALEX
# beneficiario_emenda                                               80759111000115
# ind_impositivo                                                               SIM
# tipo_parlamentar                                                      INDIVIDUAL
# valor_repasse_proposta_emenda                                             249990
# valor_repasse_emenda                                                      249990
# id_empenho                                                                282173
# nr_empenho                                                          2016NE800189
# tipo_nota                                                                      1
# desc_tipo_nota                                                  Empenho Original
# data_emissao                                                          24/05/2016
# desc_situacao_empenho                                                    Enviado
# valor_empenho                                                             100000
# nr_mov_fin                                                               4736366
# identif_fornecedor                                                44239382000186
# nome_fornecedor                PHOENIX INDUSTRIA E COMERCIO DE EQUIPAMENTOS C...
# tp_mov_financeira                                PAGAMENTO A FAVORECIDO COM OBTV
# data_pag                                                              19/02/2018
# nr_dl                                                                     024896
# desc_dl                                                              NOTA FISCAL
# vl_pago                                                                   119000
#
#                                                                     3063072  \
# id_proposta                                                         1111264
# uf_proponente                                                            PR
# munic_proponente                                                   PORECATU
# cod_munic_ibge                                                     4.12e+06
# cod_orgao_sup                                                         36000
# desc_orgao_sup                                          MINISTERIO DA SAUDE
# natureza_juridica                            Organização da Sociedade Civil
# nr_proposta                                                      31294/2016
# dia_proposta                                                     18/10/2016
# cod_orgao                                                             36000
# desc_orgao                                              MINISTERIO DA SAUDE
# modalidade                                                         CONVENIO
# identif_proponente                                           77235216000160
# nm_proponente                  ASSOCIACAO DE PAIS E AMIGOS DOS EXCEPCIONAIS
# sit_proposta                           Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                       100000
# vl_repasse_prop                                                      100000
# vl_contrapartida_prop                                                     0
# nr_convenio                                                          837025
# dia_assin_conv                                                   06/12/2016
# sit_convenio                                                    Em execução
# subsituacao_conv                                                        NaN
# situacao_publicacao                                               Publicado
# instrumento_ativo                                                       SIM
# ind_opera_obtv                                                          SIM
# dia_publ_conv                                                    16/12/2016
# dia_inic_vigenc_conv                                             06/12/2016
# dia_fim_vigenc_conv                                              08/03/2019
# dias_prest_contas                                                        60
# dia_limite_prest_contas                                          07/05/2019
# ...                                                                     ...
# vl_desembolsado_conv                                                 100000
# vl_saldo_reman_tesouro                                                  NaN
# vl_saldo_reman_convenente                                               NaN
# vl_rendimento_aplicacao                                                 NaN
# vl_ingresso_contrapartida                                               NaN
# vl_saldo_conta                                                      48583.7
# qualif_proponente                           BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                           3600020160027
# nr_emenda                                                         3.715e+07
# nome_parlamentar                                           MARCELO BELINATI
# beneficiario_emenda                                          77235216000160
# ind_impositivo                                                          SIM
# tipo_parlamentar                                                 INDIVIDUAL
# valor_repasse_proposta_emenda                                        100000
# valor_repasse_emenda                                                 100000
# id_empenho                                                           292255
# nr_empenho                                                     2016NE803051
# tipo_nota                                                                 1
# desc_tipo_nota                                             Empenho Original
# data_emissao                                                     07/11/2016
# desc_situacao_empenho                                               Enviado
# valor_empenho                                                        100000
# nr_mov_fin                                                          5061985
# identif_fornecedor                                           23192760000143
# nome_fornecedor                                        DOUGLAS B G DA SILVA
# tp_mov_financeira                           PAGAMENTO A FAVORECIDO COM OBTV
# data_pag                                                         08/10/2018
# nr_dl                                                                   233
# desc_dl                                                         NOTA FISCAL
# vl_pago                                                                8524
#
#                                                             3016975  \
# id_proposta                                                  981264
# uf_proponente                                                    RS
# munic_proponente                                            ERECHIM
# cod_munic_ibge                                          4.30700e+06
# cod_orgao_sup                                                 51000
# desc_orgao_sup                                MINISTERIO DO ESPORTE
# natureza_juridica                   Administração Pública Municipal
# nr_proposta                                              23296/2015
# dia_proposta                                             30/06/2015
# cod_orgao                                                     51000
# desc_orgao                                    MINISTERIO DO ESPORTE
# modalidade                                      CONTRATO DE REPASSE
# identif_proponente                                   87613477000120
# nm_proponente                                  MUNICIPIO DE ERECHIM
# sit_proposta                   Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                               250000
# vl_repasse_prop                                              243750
# vl_contrapartida_prop                                          6250
# nr_convenio                                                  818622
# dia_assin_conv                                           08/12/2015
# sit_convenio                                            Em execução
# subsituacao_conv                                                NaN
# situacao_publicacao                                       Publicado
# instrumento_ativo                                               SIM
# ind_opera_obtv                                                  SIM
# dia_publ_conv                                            18/12/2015
# dia_inic_vigenc_conv                                     08/12/2015
# dia_fim_vigenc_conv                                      30/12/2018
# dias_prest_contas                                                60
# dia_limite_prest_contas                                  28/02/2019
# ...                                                             ...
# vl_desembolsado_conv                                         195000
# vl_saldo_reman_tesouro                                          NaN
# vl_saldo_reman_convenente                                       NaN
# vl_rendimento_aplicacao                                         NaN
# vl_ingresso_contrapartida                                      6250
# vl_saldo_conta                                              56599.3
# qualif_proponente                   BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                   5100020150003
# nr_emenda                                                 2.407e+07
# nome_parlamentar                                 LUIZ CARLOS BUSATO
# beneficiario_emenda                                  87613477000120
# ind_impositivo                                                  SIM
# tipo_parlamentar                                         INDIVIDUAL
# valor_repasse_proposta_emenda                                243750
# valor_repasse_emenda                                         243750
# id_empenho                                                   250452
# nr_empenho                                             2015NE800162
# tipo_nota                                                         1
# desc_tipo_nota                                     Empenho Original
# data_emissao                                             27/10/2015
# desc_situacao_empenho                                       Enviado
# valor_empenho                                                243750
# nr_mov_fin                                                  4940962
# identif_fornecedor                                   22588044000117
# nome_fornecedor                                R 9 CONSTRUTORA LTDA
# tp_mov_financeira                   PAGAMENTO A FAVORECIDO COM OBTV
# data_pag                                                 17/07/2018
# nr_dl                                                           130
# desc_dl                                                 NOTA FISCAL
# vl_pago                                                     19903.5
#
#                                                                          1151682  \
# id_proposta                                                               741116
# uf_proponente                                                                 RS
# munic_proponente                                                          CANOAS
# cod_munic_ibge                                                       4.30461e+06
# cod_orgao_sup                                                              54000
# desc_orgao_sup                                             MINISTERIO DO TURISMO
# natureza_juridica                                Administração Pública Municipal
# nr_proposta                                                           47643/2013
# dia_proposta                                                          06/08/2013
# cod_orgao                                                                  54000
# desc_orgao                                                 MINISTERIO DO TURISMO
# modalidade                                                   CONTRATO DE REPASSE
# identif_proponente                                                88577416000118
# nm_proponente                                                MUNICIPIO DE CANOAS
# sit_proposta                                Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                            295625
# vl_repasse_prop                                                           268125
# vl_contrapartida_prop                                                      27500
# nr_convenio                                                               798640
# dia_assin_conv                                                        31/12/2013
# sit_convenio                            Prestação de Contas enviada para Análise
# subsituacao_conv                                                             NaN
# situacao_publicacao                                                    Publicado
# instrumento_ativo                                                            SIM
# ind_opera_obtv                                                               SIM
# dia_publ_conv                                                         20/01/2014
# dia_inic_vigenc_conv                                                  31/12/2013
# dia_fim_vigenc_conv                                                   30/06/2017
# dias_prest_contas                                                             60
# dia_limite_prest_contas                                               29/08/2017
# ...                                                                          ...
# vl_desembolsado_conv                                                      268125
# vl_saldo_reman_tesouro                                                     37534
# vl_saldo_reman_convenente                                                3849.63
# vl_rendimento_aplicacao                                                      NaN
# vl_ingresso_contrapartida                                                23944.2
# vl_saldo_conta                                                                 0
# qualif_proponente                                BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                                5400020130002
# nr_emenda                                                              2.077e+07
# nome_parlamentar                                                      MARCO MAIA
# beneficiario_emenda                                               88577416000118
# ind_impositivo                                                               NÃO
# tipo_parlamentar                                                      INDIVIDUAL
# valor_repasse_proposta_emenda                                             268125
# valor_repasse_emenda                                                      268125
# id_empenho                                                                212035
# nr_empenho                                                          2013NE801474
# tipo_nota                                                                      1
# desc_tipo_nota                                                  Empenho Original
# data_emissao                                                          27/12/2013
# desc_situacao_empenho                                                    Enviado
# valor_empenho                                                             268125
# nr_mov_fin                                                               3379995
# identif_fornecedor                                                74850231000120
# nome_fornecedor                MUNDO DA CRIANCA INDUSTRIA E COMERCIO DE BRINQ...
# tp_mov_financeira                                PAGAMENTO A FAVORECIDO COM OBTV
# data_pag                                                              30/11/2015
# nr_dl                                                                       3708
# desc_dl                                                              NOTA FISCAL
# vl_pago                                                                  9044.56
#
#                                                                          3103205
# id_proposta                                                              1231675
# uf_proponente                                                                 RS
# munic_proponente                                                    PORTO ALEGRE
# cod_munic_ibge                                                        4.3149e+06
# cod_orgao_sup                                                              22000
# desc_orgao_sup                 MINISTÉRIO DA AGRICULTURA, PECUARIA E ABASTECI...
# natureza_juridica              Administração Pública Estadual ou do Distrito ...
# nr_proposta                                                           72564/2017
# dia_proposta                                                          03/07/2017
# cod_orgao                                                                  22000
# desc_orgao                     MINISTÉRIO DA AGRICULTURA, PECUARIA E ABASTECI...
# modalidade                                                   CONTRATO DE REPASSE
# identif_proponente                                                93021632000112
# nm_proponente                    SECRETARIA DA AGRICULTURA, PECUARIA E IRRIGACAO
# sit_proposta                                Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                       7.22374e+07
# vl_repasse_prop                                                      6.95274e+07
# vl_contrapartida_prop                                                   2.71e+06
# nr_convenio                                                               850469
# dia_assin_conv                                                        31/10/2017
# sit_convenio                                                         Em execução
# subsituacao_conv                                                             NaN
# situacao_publicacao                                                    Publicado
# instrumento_ativo                                                            SIM
# ind_opera_obtv                                                               SIM
# dia_publ_conv                                                         08/11/2017
# dia_inic_vigenc_conv                                                  31/10/2017
# dia_fim_vigenc_conv                                                   30/10/2019
# dias_prest_contas                                                             60
# dia_limite_prest_contas                                               29/12/2019
# ...                                                                          ...
# vl_desembolsado_conv                                                 6.95274e+07
# vl_saldo_reman_tesouro                                                       NaN
# vl_saldo_reman_convenente                                                    NaN
# vl_rendimento_aplicacao                                                      NaN
# vl_ingresso_contrapartida                                               2.71e+06
# vl_saldo_conta                                                       3.95933e+06
# qualif_proponente                                BENEFICIARIO_EMENDA_PARLAMENTAR
# cod_programa_emenda                                                2200020170036
# nr_emenda                                                              7.122e+07
# nome_parlamentar                                    BANCADA DO RIO GRANDE DO SUL
# beneficiario_emenda                                               93021632000112
# ind_impositivo                                                               NÃO
# tipo_parlamentar                                                         BANCADA
# valor_repasse_proposta_emenda                                           9.75e+07
# valor_repasse_emenda                                                 6.95274e+07
# id_empenho                                                                314114
# nr_empenho                                                          2017NE800834
# tipo_nota                                                                      1
# desc_tipo_nota                                                  Empenho Original
# data_emissao                                                          14/09/2017
# desc_situacao_empenho                                                    Enviado
# valor_empenho                                                        1.87796e+07
# nr_mov_fin                                                               4917504
# identif_fornecedor                                                89086144000469
# nome_fornecedor                            RANDON SA IMPLEMENTOS E PARTICIPACOES
# tp_mov_financeira                                PAGAMENTO A FAVORECIDO COM OBTV
# data_pag                                                              06/07/2018
# nr_dl                                                                      64384
# desc_dl                                                              NOTA FISCAL
# vl_pago                                                                   158206
#
# [68 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3109111 entries, 0 to 3109110
# Data columns (total 68 columns):
# id_proposta                      int64
# uf_proponente                    object
# munic_proponente                 object
# cod_munic_ibge                   float64
# cod_orgao_sup                    int64
# desc_orgao_sup                   object
# natureza_juridica                object
# nr_proposta                      object
# dia_proposta                     object
# cod_orgao                        int64
# desc_orgao                       object
# modalidade                       object
# identif_proponente               int64
# nm_proponente                    object
# sit_proposta                     object
# vl_global_prop                   float64
# vl_repasse_prop                  float64
# vl_contrapartida_prop            float64
# nr_convenio                      int64
# dia_assin_conv                   object
# sit_convenio                     object
# subsituacao_conv                 object
# situacao_publicacao              object
# instrumento_ativo                object
# ind_opera_obtv                   object
# dia_publ_conv                    object
# dia_inic_vigenc_conv             object
# dia_fim_vigenc_conv              object
# dias_prest_contas                int64
# dia_limite_prest_contas          object
# ind_assinado                     object
# qtde_convenios                   int64
# qtd_ta                           float64
# qtd_prorroga                     float64
# vl_global_conv                   float64
# vl_repasse_conv                  float64
# vl_contrapartida_conv            float64
# vl_empenhado_conv                float64
# vl_desembolsado_conv             float64
# vl_saldo_reman_tesouro           float64
# vl_saldo_reman_convenente        float64
# vl_rendimento_aplicacao          float64
# vl_ingresso_contrapartida        float64
# vl_saldo_conta                   float64
# qualif_proponente                object
# cod_programa_emenda              int64
# nr_emenda                        float64
# nome_parlamentar                 object
# beneficiario_emenda              int64
# ind_impositivo                   object
# tipo_parlamentar                 object
# valor_repasse_proposta_emenda    float64
# valor_repasse_emenda             float64
# id_empenho                       int64
# nr_empenho                       object
# tipo_nota                        int64
# desc_tipo_nota                   object
# data_emissao                     object
# desc_situacao_empenho            object
# valor_empenho                    float64
# nr_mov_fin                       int64
# identif_fornecedor               object
# nome_fornecedor                  object
# tp_mov_financeira                object
# data_pag                         object
# nr_dl                            object
# desc_dl                          object
# vl_pago                          float64
# dtypes: float64(21), int64(12), object(35)
# memory usage: 1.6+ GB

# %%
df['uf_proponente'].value_counts()
# Out:
# SP    2941313
# MG      27149
# RJ      26256
# RS      19209
# PR       9239
# RN       9081
# BA       8699
# PE       6703
# SC       6668
# CE       6245
# AC       6194
# PI       5494
# PA       5175
# ES       3923
# SE       3731
# GO       3560
# AL       3439
# TO       2620
# PB       2401
# DF       2357
# MA       2278
# MS       2081
# RO       1542
# MT       1474
# RR        954
# AM        735
# AP        591
# Name: uf_proponente, dtype: int64

# %%
df['natureza_juridica'].value_counts()
# Out:
# Organização da Sociedade Civil                           2995148
# Administração Pública Municipal                            78483
# Administração Pública Estadual ou do Distrito Federal      32501
# Empresa pública/Sociedade de economia mista                 1544
# Consórcio Público                                           1435
# Name: natureza_juridica, dtype: int64

# %%
df['desc_orgao'].value_counts()
# Out:
# MINISTERIO DO TRABALHO E EMPREGO                               2904964
# MINISTERIO DA SAUDE                                              42998
# MINISTERIO DAS CIDADES                                           22989
# MINISTERIO DO ESPORTE                                            18650
# FUNDO NACIONAL ANTIDROGAS                                        16873
# MINISTÉRIO DA AGRICULTURA, PECUARIA E ABASTECIMENTO              15609
# MINISTERIO DA JUSTICA                                            14545
# MINISTERIO DOS DIREITOS HUMANOS                                  11546
# MINISTERIO DO DESENVOLVIMENTO SOCIAL                             10043
# MINISTERIO DO TURISMO                                             8413
# MINISTERIO DA CULTURA                                             7278
# COMPANHIA DE DESENV. DO VALE DO SAO FRANCISCO                     5366
# SECRETARIA ESPECIAL DE POLÍTICAS PARA AS MULHERES                 5131
# SEC.ESPEC.DE AGRIC.FAMIL.E DO DESENV.AGRARIO                      3696
# UNIVERSIDADE FEDERAL DO SUL E SUDESTE DO PARA                     3618
# MINISTERIO DO TRABALHO E PREVIDENCIA SOCIAL                       2877
# MINISTERIO DA INTEGRACAO NACIONAL                                 2750
# MINISTERIO DA DEFESA                                              1710
# MINISTÉRIO DA CIÊNCIA, TECNOLOGIA, INOVAÇÕES E COMUNICAÇÕES       1541
# INSTITUTO BRASILEIRO DE MUSEUS                                    1249
# FUNDACAO NACIONAL DE ARTES                                         966
# SUPERINT. DE DESENVOLVIMENTO DO CENTRO-OESTE                       945
# FUNDACAO NACIONAL DE SAUDE                                         807
# SECRETARIA ESPECIAL DE AQUICULTURA E PESCA/PR                      741
# PRESIDÊNCIA DA REPÚBLICA                                           704
# INSTITUTO DO PATRIMONIO HIST. E ART. NACIONAL                      611
# SUPERINTENDENCIA DO DESENVOLV. DA AMAZONIA                         508
# MINISTERIO DO MEIO AMBIENTE                                        472
# MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS                      373
# FUNDACAO CULTURAL PALMARES                                         352
# INSTIT. NAC. DE COLONIZACAO E REFORMA AGRARIA                      307
# SUPERINTENDENCIA DO DESENVOLV. DO NORDESTE                         177
# CONSELHO NACIONAL DE DES.CIENT.E TECNOLOGICO                       115
# DEPARTAMENTO NAC.DE OBRAS CONTRA AS SECAS                          105
# AGENCIA NACIONAL DO CINEMA                                          36
# SECRETARIA DE AVIAÇÃO CIVIL                                         16
# FUNDO NACIONAL PARA A CRIANCA E O ADOLESCENT                        16
# INST.CHICO MENDES DE CONSER.DA BIODIVERSIDADE                        8
# MINISTERIO DO DESENVOLVIMENTO AGRARIO                                4
# FUNDO NACIONAL DE DESENVOLVIMENTO DA EDUCACAO                        1
# EMPRESA BRASILEIRA DE PESQUISA AGROPECUARIA                          1
# Name: desc_orgao, dtype: int64

# %%
df['desc_orgao_sup'].value_counts()
# Out:
# MINISTERIO DO TRABALHO E EMPREGO                               2904964
# MINISTERIO DA SAUDE                                              43805
# MINISTERIO DA JUSTICA                                            31418
# MINISTERIO DAS CIDADES                                           22989
# MINISTERIO DO ESPORTE                                            18650
# MINISTÉRIO DA AGRICULTURA, PECUARIA E ABASTECIMENTO              15610
# MINISTERIO DOS DIREITOS HUMANOS                                  11562
# MINISTERIO DA CULTURA                                            10492
# MINISTERIO DO DESENVOLVIMENTO SOCIAL                             10043
# MINISTERIO DA INTEGRACAO NACIONAL                                 9851
# MINISTERIO DO TURISMO                                             8413
# PRESIDENCIA DA REPÚBLICA                                          6592
# SEC.ESPEC.DE AGRIC.FAMIL.E DO DESENV.AGRARIO                      3696
# MINISTERIO DA EDUCACAO                                            3619
# MINISTERIO DO TRABALHO E PREVIDENCIA SOCIAL                       2877
# MINISTERIO DA DEFESA                                              1710
# MINISTÉRIO DA CIÊNCIA, TECNOLOGIA, INOVAÇÕES E COMUNICAÇÕES       1656
# MINISTERIO DO MEIO AMBIENTE                                        480
# MINIST. DA INDUSTRIA, COM.EXTERIOR E SERVICOS                      373
# MINISTERIO DO DESENVOLVIMENTO AGRARIO                              311
# Name: desc_orgao_sup, dtype: int64

# %%
df['cod_munic_ibge'].value_counts()
# Out:
# 3550308.0    2911880
# 3303500.0      15301
# 3106200.0      12417
# 3505500.0       9326
# 2408102.0       7147
# 4314902.0       6008
# 1200401.0       5611
# 3304557.0       4783
# 1501402.0       4034
# 2211001.0       3608
# 2927408.0       3264
# 2611606.0       3020
# 3526902.0       2600
# 5300108.0       2357
# 3156700.0       1930
# 2800308.0       1927
# 2704302.0       1653
# 2308906.0       1138
# 3549904.0       1068
# 3305109.0       1032
# 2304400.0       1005
# 2607901.0        905
# 3302700.0        839
# 3136207.0        836
# 3549805.0        812
# 2908507.0        808
# 4204202.0        789
# 3205309.0        725
# 4106902.0        724
# 4314100.0        716
#               ...
# 3113909.0          1
# 2700201.0          1
# 4314456.0          1
# 2700409.0          1
# 2404705.0          1
# 3168051.0          1
# 3542909.0          1
# 3542602.0          1
# 4125100.0          1
# 2702603.0          1
# 4125357.0          1
# 3541208.0          1
# 2703601.0          1
# 2308104.0          1
# 3535606.0          1
# 3161007.0          1
# 3125804.0          1
# 1718303.0          1
# 4126405.0          1
# 4302253.0          1
# 2503308.0          1
# 3125408.0          1
# 4126900.0          1
# 3112406.0          1
# 2305902.0          1
# 3154150.0          1
# 1718709.0          1
# 2801504.0          1
# 5212709.0          1
# 3162559.0          1
# Name: cod_munic_ibge, Length: 4070, dtype: int64

# %%
df.nunique()
# Out:
# id_proposta                       16159
# uf_proponente                        27
# munic_proponente                   3934
# cod_munic_ibge                     4070
# cod_orgao_sup                        20
# desc_orgao_sup                       20
# natureza_juridica                     5
# nr_proposta                       16159
# dia_proposta                       1216
# cod_orgao                            41
# desc_orgao                           41
# modalidade                            4
# identif_proponente                 5424
# nm_proponente                      5115
# sit_proposta                          1
# vl_global_prop                    10367
# vl_repasse_prop                    3504
# vl_contrapartida_prop              8448
# nr_convenio                       16159
# dia_assin_conv                      991
# sit_convenio                          8
# subsituacao_conv                      7
# situacao_publicacao                   1
# instrumento_ativo                     1
# ind_opera_obtv                        2
# dia_publ_conv                      1133
# dia_inic_vigenc_conv               1048
# dia_fim_vigenc_conv                1636
# dias_prest_contas                    21
# dia_limite_prest_contas            1684
#                                   ...
# vl_desembolsado_conv               4687
# vl_saldo_reman_tesouro             3732
# vl_saldo_reman_convenente          2037
# vl_rendimento_aplicacao             656
# vl_ingresso_contrapartida         10113
# vl_saldo_conta                    11612
# qualif_proponente                     1
# cod_programa_emenda                1788
# nr_emenda                          6696
# nome_parlamentar                   1009
# beneficiario_emenda                5428
# ind_impositivo                        2
# tipo_parlamentar                      3
# valor_repasse_proposta_emenda      2278
# valor_repasse_emenda               3505
# id_empenho                        19187
# nr_empenho                        11573
# tipo_nota                             8
# desc_tipo_nota                        9
# data_emissao                       1059
# desc_situacao_empenho                 2
# valor_empenho                      3879
# nr_mov_fin                       111068
# identif_fornecedor                17793
# nome_fornecedor                   17555
# tp_mov_financeira                     2
# data_pag                           2059
# nr_dl                             39293
# desc_dl                              14
# vl_pago                           68285
# Length: 68, dtype: int64

# %%
fileigm = 'C:\\Users\\rodar\\Documents\\Ciencia de Dados\\IESB\\TrabalhoFinal\\siconv\\outrasfontes\\igm\\igm_modificado.csv'

# %%
igm = pd.read_csv(fileigm, sep = ',', error_bad_lines=False)

# %%
igm.shape
# Out:
# (5570, 32)

# %%
igm.describe().T
# Out:
#                               count          mean           std           min  \
# codigo_mun                   5570.0  3.253591e+06  9.849103e+05  1.100015e+06
# capital                      5570.0  4.847397e-03  6.946053e-02  0.000000e+00
# pib                          5570.0  9.544801e+05  9.502661e+06  9.678440e+03
# pib_pc                       5570.0  1.737448e+04  2.013334e+04  3.241290e+03
# participacao_transf_receita  4893.0  8.231657e+01  1.127214e+01  0.000000e+00
# servidores                   5233.0  7.713249e+02  3.209756e+03  1.000000e+00
# comissionados                5570.0  9.637127e+01  2.349945e+02  0.000000e+00
# perc_pop_econ_ativa          5565.0  9.365031e-01  1.786402e-01  2.900000e-01
# taxa_empreendedorismo        5570.0  2.509390e-01  9.801439e-02  0.000000e+00
# anos_estudo_empreendedor     5570.0  6.124378e+00  1.462946e+00  0.000000e+00
# jornada_trabalho             5570.0  4.141401e+01  5.193799e+00  0.000000e+00
# gasto_pc_saude               4881.0  6.045080e+02  2.821847e+02  3.800000e+00
# hab_p_medico                 4951.0  1.801409e+03  2.203553e+03  8.574684e+01
# exp_vida                     5565.0  7.308900e+01  2.680715e+00  6.530000e+01
# gasto_pc_educacao            4880.0  7.697755e+02  2.778418e+02  5.660000e+01
# exp_anos_estudo              5565.0  9.463639e+00  1.098269e+00  4.340000e+00
# nota_ciencias                5558.0  4.601244e+02  1.927530e+01  3.850000e+02
# nota_humanas                 5558.0  5.095269e+02  2.381608e+01  3.738000e+02
# nota_linguagem               5557.0  4.992869e+02  2.205617e+01  4.040000e+02
# nota_mat                     5557.0  4.650078e+02  2.849630e+01  3.692750e+02
# nota_redacao                 5557.0  5.018410e+02  4.490495e+01  3.200000e+02
# idhm                         4986.0  5.186256e-01  1.718472e-01  0.000000e+00
# indice_governanca            3303.0  5.019585e-01  8.370404e-02  2.580000e-01
#
#                                       25%           50%           75%  \
# codigo_mun                   2.512126e+06  3.146280e+06  4.119190e+06
# capital                      0.000000e+00  0.000000e+00  0.000000e+00
# pib                          5.922529e+04  1.301531e+05  3.426808e+05
# pib_pc                       7.077358e+03  1.262181e+04  2.126239e+04
# participacao_transf_receita  7.700000e+01  8.500000e+01  9.100000e+01
# servidores                   1.900000e+02  3.290000e+02  6.630000e+02
# comissionados                2.400000e+01  4.500000e+01  9.200000e+01
# perc_pop_econ_ativa          8.100000e-01  9.400000e-01  1.050000e+00
# taxa_empreendedorismo        1.900000e-01  2.300000e-01  2.900000e-01
# anos_estudo_empreendedor     5.039926e+00  6.049990e+00  7.175247e+00
# jornada_trabalho             3.815187e+01  4.171802e+01  4.468232e+01
# gasto_pc_saude               4.169300e+02  5.374800e+02  7.177600e+02
# hab_p_medico                 9.676362e+02  1.457062e+03  2.119679e+03
# exp_vida                     7.115000e+01  7.347000e+01  7.516000e+01
# gasto_pc_educacao            5.858925e+02  7.318250e+02  8.986250e+02
# exp_anos_estudo              8.750000e+00  9.470000e+00  1.021000e+01
# nota_ciencias                4.463243e+02  4.575499e+02  4.717528e+02
# nota_humanas                 4.929757e+02  5.089870e+02  5.264060e+02
# nota_linguagem               4.834543e+02  4.991058e+02  5.151259e+02
# nota_mat                     4.430781e+02  4.612615e+02  4.837732e+02
# nota_redacao                 4.731250e+02  5.024060e+02  5.321739e+02
# idhm                         3.750000e-01  5.350000e-01  6.590000e-01
# indice_governanca            4.380000e-01  5.040000e-01  5.660000e-01
#
#                                       max
# codigo_mun                   5.300108e+06
# capital                      1.000000e+00
# pib                          5.707062e+08
# pib_pc                       7.151937e+05
# participacao_transf_receita  1.000000e+02
# servidores                   1.342730e+05
# comissionados                7.240000e+03
# perc_pop_econ_ativa          1.640000e+00
# taxa_empreendedorismo        7.700000e-01
# anos_estudo_empreendedor     1.155316e+01
# jornada_trabalho             6.852841e+01
# gasto_pc_saude               3.066740e+03
# hab_p_medico                 7.846467e+04
# exp_vida                     7.864000e+01
# gasto_pc_educacao            3.695930e+03
# exp_anos_estudo              1.283000e+01
# nota_ciencias                5.505667e+02
# nota_humanas                 5.951600e+02
# nota_linguagem               5.716595e+02
# nota_mat                     6.034150e+02
# nota_redacao                 6.680000e+02
# idhm                         1.000000e+00
# indice_governanca            7.670000e-01

# %%
df.describe().T
# Out:
#                                    count          mean           std  \
# id_proposta                    3109111.0  7.118231e+05  2.462343e+05
# cod_munic_ibge                 3107752.0  3.528118e+06  2.430330e+05
# cod_orgao_sup                  3109111.0  3.827041e+04  4.009187e+03
# cod_orgao                      3109111.0  3.820018e+04  4.032621e+03
# identif_proponente             3109111.0  5.901374e+13  1.039109e+13
# vl_global_prop                 3109111.0  2.399769e+07  1.424299e+07
# vl_repasse_prop                3109111.0  2.235824e+07  1.400645e+07
# vl_contrapartida_prop          3109111.0  1.639458e+06  4.681478e+05
# nr_convenio                    3109111.0  7.917276e+05  2.777698e+04
# dias_prest_contas              3109111.0  4.892622e+01  1.510457e+01
# qtde_convenios                 3109111.0  1.000000e+00  0.000000e+00
# qtd_ta                         3056887.0  6.645919e+00  2.560656e+00
# qtd_prorroga                   1222480.0  1.061183e+00  4.533458e-01
# vl_global_conv                 3109111.0  2.399769e+07  1.424299e+07
# vl_repasse_conv                3109111.0  2.235824e+07  1.400645e+07
# vl_contrapartida_conv          3109111.0  1.639458e+06  4.681478e+05
# vl_empenhado_conv              3109111.0  1.074400e+07  4.682964e+06
# vl_desembolsado_conv           3108831.0  9.561015e+06  4.217692e+06
# vl_saldo_reman_tesouro           61645.0  1.237223e+05  2.653357e+05
# vl_saldo_reman_convenente        36105.0  1.019199e+04  2.342795e+04
# vl_rendimento_aplicacao        2931030.0  5.894505e+05  3.796365e+05
# vl_ingresso_contrapartida      3037093.0  9.879665e+05  5.669457e+05
# vl_saldo_conta                 2024526.0  2.927899e+06  9.187856e+05
# cod_programa_emenda            3109111.0  3.819838e+12  4.015662e+11
# nr_emenda                      3108959.0  2.569205e+07  8.283679e+06
# beneficiario_emenda            3109111.0  5.901362e+13  1.039131e+13
# valor_repasse_proposta_emenda  3109111.0  1.226283e+07  2.090586e+10
# valor_repasse_emenda           3109111.0  3.658859e+05  3.068488e+06
# id_empenho                     3109111.0  2.746623e+05  7.526683e+04
# tipo_nota                      3109111.0  1.275987e+00  8.514770e-01
# valor_empenho                  3109111.0  3.340821e+05  1.265119e+06
# nr_mov_fin                     3109111.0  3.293650e+06  1.071051e+06
# vl_pago                        3109111.0  6.645863e+03  5.614784e+04
#
#                                         min           25%           50%  \
# id_proposta                    2.123130e+05  3.859070e+05  8.867890e+05
# cod_munic_ibge                 1.100015e+06  3.550308e+06  3.550308e+06
# cod_orgao_sup                  2.000000e+04  3.800000e+04  3.800000e+04
# cod_orgao                      2.010100e+04  3.800000e+04  3.800000e+04
# identif_proponente             7.290002e+08  6.096500e+13  6.096500e+13
# vl_global_prop                 9.000000e+01  8.164716e+06  3.557852e+07
# vl_repasse_prop                9.000000e+01  6.498331e+06  3.379460e+07
# vl_contrapartida_prop          0.000000e+00  1.666384e+06  1.783917e+06
# nr_convenio                    7.331720e+05  7.551580e+05  8.114850e+05
# dias_prest_contas              0.000000e+00  3.000000e+01  6.000000e+01
# qtde_convenios                 1.000000e+00  1.000000e+00  1.000000e+00
# qtd_ta                         1.000000e+00  5.000000e+00  5.000000e+00
# qtd_prorroga                   1.000000e+00  1.000000e+00  1.000000e+00
# vl_global_conv                 9.000000e+01  8.164716e+06  3.557852e+07
# vl_repasse_conv                9.000000e+01  6.498331e+06  3.379460e+07
# vl_contrapartida_conv          0.000000e+00  1.666384e+06  1.783917e+06
# vl_empenhado_conv              0.000000e+00  7.148289e+06  1.365168e+07
# vl_desembolsado_conv           9.000000e+01  6.498331e+06  1.205092e+07
# vl_saldo_reman_tesouro         1.000000e-02  1.297615e+04  4.268197e+04
# vl_saldo_reman_convenente      1.000000e-02  3.654500e+02  2.238140e+03
# vl_rendimento_aplicacao        2.600000e+01  1.015262e+05  8.842050e+05
# vl_ingresso_contrapartida      0.000000e+00  6.388783e+05  6.388783e+05
# vl_saldo_conta                 0.000000e+00  3.206297e+06  3.206297e+06
# cod_programa_emenda            2.010120e+12  3.800020e+12  3.800020e+12
# nr_emenda                      1.000000e+07  1.997002e+07  2.520000e+07
# beneficiario_emenda            7.290002e+08  6.096500e+13  6.096500e+13
# valor_repasse_proposta_emenda  1.000000e+00  1.000000e+05  2.000000e+05
# valor_repasse_emenda           1.000000e+00  1.000000e+05  2.000000e+05
# id_empenho                     7.061500e+04  2.044650e+05  2.591990e+05
# tipo_nota                      1.000000e+00  1.000000e+00  1.000000e+00
# valor_empenho                 -5.933860e+07  1.000000e+05  2.000000e+05
# nr_mov_fin                     1.029010e+05  2.832443e+06  3.347296e+06
# vl_pago                       -5.347300e+02  7.079400e+02  1.545470e+03
#
#                                         75%           max
# id_proposta                    8.867890e+05  1.361556e+06
# cod_munic_ibge                 3.550308e+06  5.300108e+06
# cod_orgao_sup                  3.800000e+04  8.100000e+04
# cod_orgao                      3.800000e+04  8.100000e+04
# identif_proponente             6.096500e+13  9.871488e+13
# vl_global_prop                 3.557852e+07  8.521845e+07
# vl_repasse_prop                3.379460e+07  7.711440e+07
# vl_contrapartida_prop          1.783917e+06  2.258045e+07
# nr_convenio                    8.114850e+05  8.745790e+05
# dias_prest_contas              6.000000e+01  8.110000e+02
# qtde_convenios                 1.000000e+00  1.000000e+00
# qtd_ta                         1.000000e+01  1.600000e+01
# qtd_prorroga                   1.000000e+00  1.500000e+01
# vl_global_conv                 3.557852e+07  8.521845e+07
# vl_repasse_conv                3.379460e+07  7.711440e+07
# vl_contrapartida_conv          1.783917e+06  2.258045e+07
# vl_empenhado_conv              1.365168e+07  7.711440e+07
# vl_desembolsado_conv           1.205092e+07  7.711440e+07
# vl_saldo_reman_tesouro         1.311399e+05  6.890955e+06
# vl_saldo_reman_convenente      1.463468e+04  4.305954e+05
# vl_rendimento_aplicacao        8.842050e+05  1.457601e+06
# vl_ingresso_contrapartida      1.666384e+06  2.258045e+07
# vl_saldo_conta                 3.206297e+06  4.785365e+07
# cod_programa_emenda            3.800020e+12  8.100020e+12
# nr_emenda                      2.910000e+07  9.048001e+07
# beneficiario_emenda            6.096500e+13  9.871488e+13
# valor_repasse_proposta_emenda  2.000000e+05  3.686262e+13
# valor_repasse_emenda           2.000000e+05  7.711440e+07
# id_empenho                     3.741440e+05  3.742890e+05
# tipo_nota                      1.000000e+00  1.500000e+01
# valor_empenho                  2.998488e+05  6.157566e+07
# nr_mov_fin                     4.067159e+06  5.089781e+06
# vl_pago                        2.904180e+03  7.954000e+06

# %%
df['cod_mun_chave'] = df['cod_munic_ibge']

# igm.rename(columns={'Município':'mun'}, inplace=True)
# df.rename(columns={'NOME DO MUNICÍPIO':'mun'}, inplace=True)

# %%
igm['cod_mun_chave'] = igm['codigo_mun']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3109111 entries, 0 to 3109110
# Data columns (total 69 columns):
# id_proposta                      int64
# uf_proponente                    object
# munic_proponente                 object
# cod_munic_ibge                   float64
# cod_orgao_sup                    int64
# desc_orgao_sup                   object
# natureza_juridica                object
# nr_proposta                      object
# dia_proposta                     object
# cod_orgao                        int64
# desc_orgao                       object
# modalidade                       object
# identif_proponente               int64
# nm_proponente                    object
# sit_proposta                     object
# vl_global_prop                   float64
# vl_repasse_prop                  float64
# vl_contrapartida_prop            float64
# nr_convenio                      int64
# dia_assin_conv                   object
# sit_convenio                     object
# subsituacao_conv                 object
# situacao_publicacao              object
# instrumento_ativo                object
# ind_opera_obtv                   object
# dia_publ_conv                    object
# dia_inic_vigenc_conv             object
# dia_fim_vigenc_conv              object
# dias_prest_contas                int64
# dia_limite_prest_contas          object
# ind_assinado                     object
# qtde_convenios                   int64
# qtd_ta                           float64
# qtd_prorroga                     float64
# vl_global_conv                   float64
# vl_repasse_conv                  float64
# vl_contrapartida_conv            float64
# vl_empenhado_conv                float64
# vl_desembolsado_conv             float64
# vl_saldo_reman_tesouro           float64
# vl_saldo_reman_convenente        float64
# vl_rendimento_aplicacao          float64
# vl_ingresso_contrapartida        float64
# vl_saldo_conta                   float64
# qualif_proponente                object
# cod_programa_emenda              int64
# nr_emenda                        float64
# nome_parlamentar                 object
# beneficiario_emenda              int64
# ind_impositivo                   object
# tipo_parlamentar                 object
# valor_repasse_proposta_emenda    float64
# valor_repasse_emenda             float64
# id_empenho                       int64
# nr_empenho                       object
# tipo_nota                        int64
# desc_tipo_nota                   object
# data_emissao                     object
# desc_situacao_empenho            object
# valor_empenho                    float64
# nr_mov_fin                       int64
# identif_fornecedor               object
# nome_fornecedor                  object
# tp_mov_financeira                object
# data_pag                         object
# nr_dl                            object
# desc_dl                          object
# vl_pago                          float64
# cod_mun_chave                    float64
# dtypes: float64(22), int64(12), object(35)
# memory usage: 1.6+ GB

# %%
igm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 33 columns):
# regiao                         5570 non-null object
# estado                         5570 non-null object
# municipio                      5570 non-null object
# codigo_mun                     5570 non-null int64
# capital                        5570 non-null int64
# porte                          5570 non-null object
# populacao                      5570 non-null object
# area                           5570 non-null object
# densidade_dem                  5566 non-null object
# pib                            5570 non-null float64
# pib_pc                         5570 non-null float64
# participacao_transf_receita    4893 non-null float64
# servidores                     5233 non-null float64
# comissionados                  5570 non-null float64
# comissionados_por_servidor     5570 non-null object
# perc_pop_econ_ativa            5565 non-null float64
# taxa_empreendedorismo          5570 non-null float64
# anos_estudo_empreendedor       5570 non-null float64
# jornada_trabalho               5570 non-null float64
# gasto_pc_saude                 4881 non-null float64
# hab_p_medico                   4951 non-null float64
# exp_vida                       5565 non-null float64
# gasto_pc_educacao              4880 non-null float64
# exp_anos_estudo                5565 non-null float64
# nota_ciencias                  5558 non-null float64
# nota_humanas                   5558 non-null float64
# nota_linguagem                 5557 non-null float64
# nota_mat                       5557 non-null float64
# nota_redacao                   5557 non-null float64
# idhm                           4986 non-null float64
# ranking_igm                    3303 non-null object
# indice_governanca              3303 non-null float64
# cod_mun_chave                  5570 non-null int64
# dtypes: float64(21), int64(3), object(9)
# memory usage: 1.4+ MB

# %%
result = pd.merge(df, igm, on='cod_mun_chave')

# %%
result.shape
# Out:
# (3107752, 101)

# %%
df.shape
# Out:
# (3109111, 69)

# %%
igm.shape
# Out:
# (5570, 33)

# %%
result.head(6).T
# Out:
#                                                                          0  \
# id_proposta                                                         288734
# uf_proponente                                                           PI
# munic_proponente                                             DOM INOCENCIO
# cod_munic_ibge                                                 2.20345e+06
# cod_orgao_sup                                                        53000
# desc_orgao_sup                           MINISTERIO DA INTEGRACAO NACIONAL
# natureza_juridica                          Administração Pública Municipal
# nr_proposta                                                     43989/2010
# dia_proposta                                                    19/04/2010
# cod_orgao                                                            22203
# desc_orgao                   COMPANHIA DE DESENV. DO VALE DO SAO FRANCISCO
# modalidade                                                        CONVENIO
# identif_proponente                                          23500002000145
# nm_proponente                                   MUNICIPIO DE DOM INOCENCIO
# sit_proposta                          Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                      229239
# vl_repasse_prop                                                     190000
# vl_contrapartida_prop                                              39238.5
# nr_convenio                                                         733172
# dia_assin_conv                                                  29/12/2011
# sit_convenio                                                   Em execução
# subsituacao_conv                                                       NaN
# situacao_publicacao                                              Publicado
# instrumento_ativo                                                      SIM
# ind_opera_obtv                                                         NÃO
# dia_publ_conv                                                   30/12/2011
# dia_inic_vigenc_conv                                            29/12/2011
# dia_fim_vigenc_conv                                             22/11/2018
# dias_prest_contas                                                       30
# dia_limite_prest_contas                                         22/12/2018
# ...                                                                    ...
# municipio                                                    DOM INOCENCIO
# codigo_mun                                                         2203453
# capital                                                                  0
# porte                                                      Pequeno porte 1
# populacao                                                            9,396
# area                                                              3,870.17
# densidade_dem                                                          2.4
# pib                                                                37077.1
# pib_pc                                                             3959.54
# participacao_transf_receita                                             98
# servidores                                                             217
# comissionados                                                           79
# comissionados_por_servidor                                             36%
# perc_pop_econ_ativa                                                   0.89
# taxa_empreendedorismo                                                 0.15
# anos_estudo_empreendedor                                           4.38873
# jornada_trabalho                                                    33.134
# gasto_pc_saude                                                      356.85
# hab_p_medico                                                        1875.2
# exp_vida                                                             70.33
# gasto_pc_educacao                                                   805.23
# exp_anos_estudo                                                       9.36
# nota_ciencias                                                      430.524
# nota_humanas                                                       453.517
# nota_linguagem                                                     479.766
# nota_mat                                                           442.772
# nota_redacao                                                       458.621
# idhm                                                                 0.253
# ranking_igm                                                          2952º
# indice_governanca                                                    0.393
#
#                                                                          1  \
# id_proposta                                                         288734
# uf_proponente                                                           PI
# munic_proponente                                             DOM INOCENCIO
# cod_munic_ibge                                                 2.20345e+06
# cod_orgao_sup                                                        53000
# desc_orgao_sup                           MINISTERIO DA INTEGRACAO NACIONAL
# natureza_juridica                          Administração Pública Municipal
# nr_proposta                                                     43989/2010
# dia_proposta                                                    19/04/2010
# cod_orgao                                                            22203
# desc_orgao                   COMPANHIA DE DESENV. DO VALE DO SAO FRANCISCO
# modalidade                                                        CONVENIO
# identif_proponente                                          23500002000145
# nm_proponente                                   MUNICIPIO DE DOM INOCENCIO
# sit_proposta                          Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                      229239
# vl_repasse_prop                                                     190000
# vl_contrapartida_prop                                              39238.5
# nr_convenio                                                         733172
# dia_assin_conv                                                  29/12/2011
# sit_convenio                                                   Em execução
# subsituacao_conv                                                       NaN
# situacao_publicacao                                              Publicado
# instrumento_ativo                                                      SIM
# ind_opera_obtv                                                         NÃO
# dia_publ_conv                                                   30/12/2011
# dia_inic_vigenc_conv                                            29/12/2011
# dia_fim_vigenc_conv                                             22/11/2018
# dias_prest_contas                                                       30
# dia_limite_prest_contas                                         22/12/2018
# ...                                                                    ...
# municipio                                                    DOM INOCENCIO
# codigo_mun                                                         2203453
# capital                                                                  0
# porte                                                      Pequeno porte 1
# populacao                                                            9,396
# area                                                              3,870.17
# densidade_dem                                                          2.4
# pib                                                                37077.1
# pib_pc                                                             3959.54
# participacao_transf_receita                                             98
# servidores                                                             217
# comissionados                                                           79
# comissionados_por_servidor                                             36%
# perc_pop_econ_ativa                                                   0.89
# taxa_empreendedorismo                                                 0.15
# anos_estudo_empreendedor                                           4.38873
# jornada_trabalho                                                    33.134
# gasto_pc_saude                                                      356.85
# hab_p_medico                                                        1875.2
# exp_vida                                                             70.33
# gasto_pc_educacao                                                   805.23
# exp_anos_estudo                                                       9.36
# nota_ciencias                                                      430.524
# nota_humanas                                                       453.517
# nota_linguagem                                                     479.766
# nota_mat                                                           442.772
# nota_redacao                                                       458.621
# idhm                                                                 0.253
# ranking_igm                                                          2952º
# indice_governanca                                                    0.393
#
#                                                                          2  \
# id_proposta                                                         288734
# uf_proponente                                                           PI
# munic_proponente                                             DOM INOCENCIO
# cod_munic_ibge                                                 2.20345e+06
# cod_orgao_sup                                                        53000
# desc_orgao_sup                           MINISTERIO DA INTEGRACAO NACIONAL
# natureza_juridica                          Administração Pública Municipal
# nr_proposta                                                     43989/2010
# dia_proposta                                                    19/04/2010
# cod_orgao                                                            22203
# desc_orgao                   COMPANHIA DE DESENV. DO VALE DO SAO FRANCISCO
# modalidade                                                        CONVENIO
# identif_proponente                                          23500002000145
# nm_proponente                                   MUNICIPIO DE DOM INOCENCIO
# sit_proposta                          Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                      229239
# vl_repasse_prop                                                     190000
# vl_contrapartida_prop                                              39238.5
# nr_convenio                                                         733172
# dia_assin_conv                                                  29/12/2011
# sit_convenio                                                   Em execução
# subsituacao_conv                                                       NaN
# situacao_publicacao                                              Publicado
# instrumento_ativo                                                      SIM
# ind_opera_obtv                                                         NÃO
# dia_publ_conv                                                   30/12/2011
# dia_inic_vigenc_conv                                            29/12/2011
# dia_fim_vigenc_conv                                             22/11/2018
# dias_prest_contas                                                       30
# dia_limite_prest_contas                                         22/12/2018
# ...                                                                    ...
# municipio                                                    DOM INOCENCIO
# codigo_mun                                                         2203453
# capital                                                                  0
# porte                                                      Pequeno porte 1
# populacao                                                            9,396
# area                                                              3,870.17
# densidade_dem                                                          2.4
# pib                                                                37077.1
# pib_pc                                                             3959.54
# participacao_transf_receita                                             98
# servidores                                                             217
# comissionados                                                           79
# comissionados_por_servidor                                             36%
# perc_pop_econ_ativa                                                   0.89
# taxa_empreendedorismo                                                 0.15
# anos_estudo_empreendedor                                           4.38873
# jornada_trabalho                                                    33.134
# gasto_pc_saude                                                      356.85
# hab_p_medico                                                        1875.2
# exp_vida                                                             70.33
# gasto_pc_educacao                                                   805.23
# exp_anos_estudo                                                       9.36
# nota_ciencias                                                      430.524
# nota_humanas                                                       453.517
# nota_linguagem                                                     479.766
# nota_mat                                                           442.772
# nota_redacao                                                       458.621
# idhm                                                                 0.253
# ranking_igm                                                          2952º
# indice_governanca                                                    0.393
#
#                                                                          3  \
# id_proposta                                                         288734
# uf_proponente                                                           PI
# munic_proponente                                             DOM INOCENCIO
# cod_munic_ibge                                                 2.20345e+06
# cod_orgao_sup                                                        53000
# desc_orgao_sup                           MINISTERIO DA INTEGRACAO NACIONAL
# natureza_juridica                          Administração Pública Municipal
# nr_proposta                                                     43989/2010
# dia_proposta                                                    19/04/2010
# cod_orgao                                                            22203
# desc_orgao                   COMPANHIA DE DESENV. DO VALE DO SAO FRANCISCO
# modalidade                                                        CONVENIO
# identif_proponente                                          23500002000145
# nm_proponente                                   MUNICIPIO DE DOM INOCENCIO
# sit_proposta                          Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                      229239
# vl_repasse_prop                                                     190000
# vl_contrapartida_prop                                              39238.5
# nr_convenio                                                         733172
# dia_assin_conv                                                  29/12/2011
# sit_convenio                                                   Em execução
# subsituacao_conv                                                       NaN
# situacao_publicacao                                              Publicado
# instrumento_ativo                                                      SIM
# ind_opera_obtv                                                         NÃO
# dia_publ_conv                                                   30/12/2011
# dia_inic_vigenc_conv                                            29/12/2011
# dia_fim_vigenc_conv                                             22/11/2018
# dias_prest_contas                                                       30
# dia_limite_prest_contas                                         22/12/2018
# ...                                                                    ...
# municipio                                                    DOM INOCENCIO
# codigo_mun                                                         2203453
# capital                                                                  0
# porte                                                      Pequeno porte 1
# populacao                                                            9,396
# area                                                              3,870.17
# densidade_dem                                                          2.4
# pib                                                                37077.1
# pib_pc                                                             3959.54
# participacao_transf_receita                                             98
# servidores                                                             217
# comissionados                                                           79
# comissionados_por_servidor                                             36%
# perc_pop_econ_ativa                                                   0.89
# taxa_empreendedorismo                                                 0.15
# anos_estudo_empreendedor                                           4.38873
# jornada_trabalho                                                    33.134
# gasto_pc_saude                                                      356.85
# hab_p_medico                                                        1875.2
# exp_vida                                                             70.33
# gasto_pc_educacao                                                   805.23
# exp_anos_estudo                                                       9.36
# nota_ciencias                                                      430.524
# nota_humanas                                                       453.517
# nota_linguagem                                                     479.766
# nota_mat                                                           442.772
# nota_redacao                                                       458.621
# idhm                                                                 0.253
# ranking_igm                                                          2952º
# indice_governanca                                                    0.393
#
#                                                                          4  \
# id_proposta                                                         288734
# uf_proponente                                                           PI
# munic_proponente                                             DOM INOCENCIO
# cod_munic_ibge                                                 2.20345e+06
# cod_orgao_sup                                                        53000
# desc_orgao_sup                           MINISTERIO DA INTEGRACAO NACIONAL
# natureza_juridica                          Administração Pública Municipal
# nr_proposta                                                     43989/2010
# dia_proposta                                                    19/04/2010
# cod_orgao                                                            22203
# desc_orgao                   COMPANHIA DE DESENV. DO VALE DO SAO FRANCISCO
# modalidade                                                        CONVENIO
# identif_proponente                                          23500002000145
# nm_proponente                                   MUNICIPIO DE DOM INOCENCIO
# sit_proposta                          Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                      229239
# vl_repasse_prop                                                     190000
# vl_contrapartida_prop                                              39238.5
# nr_convenio                                                         733172
# dia_assin_conv                                                  29/12/2011
# sit_convenio                                                   Em execução
# subsituacao_conv                                                       NaN
# situacao_publicacao                                              Publicado
# instrumento_ativo                                                      SIM
# ind_opera_obtv                                                         NÃO
# dia_publ_conv                                                   30/12/2011
# dia_inic_vigenc_conv                                            29/12/2011
# dia_fim_vigenc_conv                                             22/11/2018
# dias_prest_contas                                                       30
# dia_limite_prest_contas                                         22/12/2018
# ...                                                                    ...
# municipio                                                    DOM INOCENCIO
# codigo_mun                                                         2203453
# capital                                                                  0
# porte                                                      Pequeno porte 1
# populacao                                                            9,396
# area                                                              3,870.17
# densidade_dem                                                          2.4
# pib                                                                37077.1
# pib_pc                                                             3959.54
# participacao_transf_receita                                             98
# servidores                                                             217
# comissionados                                                           79
# comissionados_por_servidor                                             36%
# perc_pop_econ_ativa                                                   0.89
# taxa_empreendedorismo                                                 0.15
# anos_estudo_empreendedor                                           4.38873
# jornada_trabalho                                                    33.134
# gasto_pc_saude                                                      356.85
# hab_p_medico                                                        1875.2
# exp_vida                                                             70.33
# gasto_pc_educacao                                                   805.23
# exp_anos_estudo                                                       9.36
# nota_ciencias                                                      430.524
# nota_humanas                                                       453.517
# nota_linguagem                                                     479.766
# nota_mat                                                           442.772
# nota_redacao                                                       458.621
# idhm                                                                 0.253
# ranking_igm                                                          2952º
# indice_governanca                                                    0.393
#
#                                                                          5
# id_proposta                                                         288734
# uf_proponente                                                           PI
# munic_proponente                                             DOM INOCENCIO
# cod_munic_ibge                                                 2.20345e+06
# cod_orgao_sup                                                        53000
# desc_orgao_sup                           MINISTERIO DA INTEGRACAO NACIONAL
# natureza_juridica                          Administração Pública Municipal
# nr_proposta                                                     43989/2010
# dia_proposta                                                    19/04/2010
# cod_orgao                                                            22203
# desc_orgao                   COMPANHIA DE DESENV. DO VALE DO SAO FRANCISCO
# modalidade                                                        CONVENIO
# identif_proponente                                          23500002000145
# nm_proponente                                   MUNICIPIO DE DOM INOCENCIO
# sit_proposta                          Proposta/Plano de Trabalho Aprovados
# vl_global_prop                                                      229239
# vl_repasse_prop                                                     190000
# vl_contrapartida_prop                                              39238.5
# nr_convenio                                                         733172
# dia_assin_conv                                                  29/12/2011
# sit_convenio                                                   Em execução
# subsituacao_conv                                                       NaN
# situacao_publicacao                                              Publicado
# instrumento_ativo                                                      SIM
# ind_opera_obtv                                                         NÃO
# dia_publ_conv                                                   30/12/2011
# dia_inic_vigenc_conv                                            29/12/2011
# dia_fim_vigenc_conv                                             22/11/2018
# dias_prest_contas                                                       30
# dia_limite_prest_contas                                         22/12/2018
# ...                                                                    ...
# municipio                                                    DOM INOCENCIO
# codigo_mun                                                         2203453
# capital                                                                  0
# porte                                                      Pequeno porte 1
# populacao                                                            9,396
# area                                                              3,870.17
# densidade_dem                                                          2.4
# pib                                                                37077.1
# pib_pc                                                             3959.54
# participacao_transf_receita                                             98
# servidores                                                             217
# comissionados                                                           79
# comissionados_por_servidor                                             36%
# perc_pop_econ_ativa                                                   0.89
# taxa_empreendedorismo                                                 0.15
# anos_estudo_empreendedor                                           4.38873
# jornada_trabalho                                                    33.134
# gasto_pc_saude                                                      356.85
# hab_p_medico                                                        1875.2
# exp_vida                                                             70.33
# gasto_pc_educacao                                                   805.23
# exp_anos_estudo                                                       9.36
# nota_ciencias                                                      430.524
# nota_humanas                                                       453.517
# nota_linguagem                                                     479.766
# nota_mat                                                           442.772
# nota_redacao                                                       458.621
# idhm                                                                 0.253
# ranking_igm                                                          2952º
# indice_governanca                                                    0.393
#
# [101 rows x 6 columns]
